# %% [markdown]
# # Quantum Computing (Bell States) - Grazia Edumaba Graham

# %% [markdown]
# ### 𝗢𝘂𝘁𝗹𝗶𝗻𝗲
# 1. Bell States Analogy
# 2. Bell States Types
# 3. Bell States Application
# 4. Some Jargons in Quantum Computing.
# 5. Quick Jupyter Notebook Guide Creating A Bell State.
# 6. Interpretation
# 7. Conclusion
# 8. References

# %% [markdown]
# ## 1.Bell States Analogy
# ### 𝗠𝗲𝗱𝗶𝗰𝗮𝗹 𝗔𝗻𝗮𝗹𝗼𝗴𝘆 (𝗣𝗶𝗹𝗹𝘀)
#
# In quantum computing, the fundamental unit of information is the 𝗾𝘂𝗯𝗶𝘁, which is analogous to a classical bit but with unique quantum properties. Let's relate this to our pill analogy:
#
# Quantum Pill Analogy for 𝗤𝘂𝗯𝗶𝘁𝘀:
#
# Imagine a special quantum pill that can be split into two halves. Each half represents a qubit.
#
# Key properties of our quantum pill (𝗾𝘂𝗯𝗶𝘁):
#
# * Color Superposition: Before observation, each pill half exists in a superposition of blue and yellow.
# * Measurement: When observed, a pill half instantly becomes either blue or yellow.
# * Entanglement: The two halves of the pill are entangled, meaning their colors are correlated in specific ways.
#
# 𝗤𝘂𝗯𝗶𝘁 States:
#
# * |0⟩: Represented by blue in our pill analogy
# * |1⟩: Represented by yellow in our pill analogy
# * Superposition: The state before measurement, where the pill half is both blue and yellow simultaneously
#
# Bell states represent entangled quantum states creating a phenomenon known as 𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗘𝗻𝘁𝗮𝗻𝗴𝗹𝗲𝗺𝗲𝗻𝘁.
#
# ![image.png](data:image/png;base64,...)
#
# Imagine this scenario:
#
# A quantum pharmacist creates a special pill that splits into two halves:
# - One half goes to 𝗔𝗹𝗶𝗰𝗲 (in New York)
# - The other half goes to  𝗮𝗻𝗱 𝗕𝗼𝗯(in Tokyo)
#
# Key properties of this quantum pill:
# 1. Each half can be either blue or yellow when observed.
# 2. Before observation, each half is in a superposition of blue and yellow.
# 3. The halves are entangled, meaning their colors are correlated.
#
#  𝗔𝗹𝗶𝗰𝗲 𝗮𝗻𝗱 𝗕𝗼𝗯 :
# - Alice and Bob are the observers, not the pill halves themselves.
# - They each have a device to "measure" the color of their pill half.
#
# Measurement process:
# - When Alice measures her half, it instantly affects Bob's half, regardless of distance.
# - If Alice's half turns blue, Bob's will always be blue. If Alice's is yellow, Bob's will always be yellow.
# - This happens instantaneously, faster than any classical communication between New York and Tokyo.
#
# Remember:
# - The pill halves represent the entangled qubits.
# - Alice and Bob are the observers measuring the states of these quantum pill halves.
# - The instantaneous correlation between the halves, regardless of distance, illustrates the non-local nature of quantum entanglement.
#
# This analogy helps visualize the concept, but keep in mind that real quantum systems are much more complex and don't have classical equivalents like physical pills.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.Bell States Types?
#
# Let's first understand Quantum entanglement : Quantum entanglement is a phenomenon where two or more qubits become correlated in such a way that the quantum state of each qubit cannot be described independently.
#
# Bell states,are specific quantum states of two qubits that are maximally entangled. There are 𝗳𝗼𝘂𝗿 Bell states, which are crucial in quantum computing for demonstrating quantum entanglement.
#
# * Each of these quantum pills represents a different type of Bell state, a fundamental concept in quantum computing that showcases the mysterious phenomenon of quantum entanglement. Whether 𝗔𝗹𝗶𝗰𝗲 𝗮𝗻𝗱 𝗕𝗼𝗯 are perfectly in sync or always mirroring each other, they are forever connected—just like the two halves of these magical pills!
#
# ### Breakdown of Bell States
#
#
# ![image.png](data:image/png;base64,...)
#
# Let’s break down the four Bell states using a pill analogy to make it even more relatable and fun.
#
# 1. Φ+ (𝗣𝗵𝗶-𝗽𝗹𝘂𝘀) 𝘀𝘁𝗮𝘁𝗲: |Φ+⟩ = 1/√2 (|00⟩ + |11⟩)
# This state is an equal superposition of both qubits being in the |0⟩ state and both qubits being in the |1⟩ state. If you measure either qubit, you have a 50% chance of getting 0 and a 50% chance of getting 1. However, whatever result you get, you know the other qubit will have the same value.
#
# * 𝗥𝗲𝗮𝗹 𝗟𝗶𝗳𝗲 𝗔𝗻𝗮𝗹𝗼𝗴𝘆: The "𝗣𝗲𝗿𝗳𝗲𝗰𝘁 𝗠𝗮𝘁𝗰𝗵" Pill - It's like Alice and Bob each taking half of a mood-stabilizing pill. If Alice feels calm (blue), Bob also feels calm. If Alice feels energetic (yellow), Bob also feels energetic. Their moods always match, no matter the distance between them.
#
# 2. Φ- (𝗣𝗵𝗶-𝗺𝗶𝗻𝘂𝘀) 𝘀𝘁𝗮𝘁𝗲:|Φ-⟩ = 1/√2 (|00⟩ - |11⟩)
# This is similar to Ψ+, but with a negative sign before the |11⟩ term. This negative sign introduces a phase difference between the two terms, which is crucial in quantum mechanics. Like Ψ+, measuring either qubit gives a 50% chance of 0 or 1, and the results will always match.
#
# * 𝗥𝗲𝗮𝗹 𝗟𝗶𝗳𝗲 𝗔𝗻𝗮𝗹𝗼𝗴𝘆: The "𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗧𝘄𝗶𝗻𝘀" Pill-Imagine a pill that makes Alice and Bob experience the same mood, but they arrive at it differently. If they both end up calm (blue), Alice might have gradually relaxed while Bob suddenly mellowed out. The end result is the same, but the journey differs.
#
# 3. Ψ+ (𝗣𝘀𝗶-𝗽𝗹𝘂𝘀) 𝘀𝘁𝗮𝘁𝗲:|Φ+⟩ = 1/√2 (|01⟩ + |10⟩)
# This state is an equal superposition of the first qubit being 0 and the second 1, and vice versa. If you measure either qubit, you still have a 50% chance of getting 0 or 1. However, whatever result you get, you know the other qubit will have the opposite value.
#
# * 𝗥𝗲𝗮𝗹 𝗟𝗶𝗳𝗲 𝗔𝗻𝗮𝗹𝗼𝗴𝘆: The "𝗖𝗼𝗺𝗽𝗹𝗲𝗺𝗲𝗻𝘁𝗮𝗿𝘆 𝗖𝗼𝗹𝗼𝗿𝘀" Pill - This is like a balance pill where one person's energy is always complemented by the other's calmness. If Alice takes her half and feels energized (yellow), Bob's half makes him feel calm (blue). They're always in perfect balance, one active and one relaxed.
#
# 4.  Ψ- (𝗣𝘀𝗶-𝗺𝗶𝗻𝘂𝘀) 𝘀𝘁𝗮𝘁𝗲: |Ψ-⟩ = 1/√2 (|01⟩ - |10⟩)
# This is similar to Ψ+, but with a negative sign before the |10⟩ term. Again, this negative sign introduces a phase difference. Like Ψ+, measuring either qubit gives a 50% chance of 0 or 1, and the results will always be opposite.
#
# * 𝗥𝗲𝗮𝗹 𝗟𝗶𝗳𝗲 𝗔𝗻𝗮𝗹𝗼𝗴𝘆: The "𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗢𝗽𝗽𝗼𝘀𝗶𝘁𝗲𝘀" Pill - Think of this as an advanced version of the balance pill. Not only does it make Alice and Bob experience opposite states (energized vs. calm), but it also influences how they transition between states. If Alice's energy gradually increases, Bob might experience a sudden onset of calmness.
#
# ### Summary of the Pill Analogy for Bell States:
#
# * |Φ⁺⟩: Both halves always the same color (blue-blue or yellow-yellow) — the "𝗣𝗲𝗿𝗳𝗲𝗰𝘁 𝗠𝗮𝘁𝗰𝗵" pill.
# * |Φ⁻⟩: Both halves always the same color, but with a quantum twist — the "𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗧𝘄𝗶𝗻𝘀" pill.
# * |Ψ⁺⟩: Halves always opposite colors (blue-yellow or yellow-blue) — the "𝗖𝗼𝗺𝗽𝗹𝗲𝗺𝗲𝗻𝘁𝗮𝗿𝘆 𝗖𝗼𝗹𝗼𝗿𝘀" pill.
# * |Ψ⁻⟩: Halves always opposite colors, with a quantum twist — the "𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗢𝗽𝗽𝗼𝘀𝗶𝘁𝗲𝘀" pill.

# %% [markdown]
# ## 3.Bell States Application
# These states are fundamental in :
#
# 1. 𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗧𝗲𝗹𝗲𝗽𝗼𝗿𝘁𝗮𝘁𝗶𝗼𝗻: Allows the transfer of a quantum state from one location to another, using classical communication and a shared entangled state.
#
# 2. 𝗦𝘂𝗽𝗲𝗿𝗱𝗲𝗻𝘀𝗲 𝗖𝗼𝗱𝗶𝗻𝗴: Enables the transmission of two classical bits of information by manipulating only one qubit of an entangled pair.
#
# 3. 𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗞𝗲𝘆 𝗗𝗶𝘀𝘁𝗿𝗶𝗯𝘂𝘁𝗶𝗼𝗻: Provides a secure method for sharing encryption keys, with security guaranteed by the laws of quantum mechanics.

# %% [markdown]
# ## 4.Some Jargons in Quantum Computing.
# 1. **Qubits**:
# In quantum computing, the basic unit of information is a qubit (quantum bit). A qubit, unlike a classical bit, can be in a state of:
#
# ∣
# 0
# ⟩
# ∣0⟩ (like a classical 0)
# ∣
# 1
# ⟩
# ∣1⟩ (like a classical 1)
# Any combination (or superposition) of
# ∣
# 0
# ⟩
# ∣0⟩ and
# ∣
# 1
# ⟩
# ∣1⟩, represented as
# 𝛼
# ∣
# 0
# ⟩
# +
# 𝛽
# ∣
# 1
# ⟩
# **α∣0⟩+β∣1⟩**, where
# 𝛼
# α and
# 𝛽
# β are complex numbers.
#
# ![image.png](data:image/png;base64,...)
#
# * 𝗤𝘂𝗯𝗶𝘁:Short for "quantum bit," a qubit is the basic unit of information in quantum computing, similar to how a bit is the basic unit in classical computing. While a classical bit can be either 0 or 1, a qubit can be in a superposition of both states simultaneously.
#
# ![image.png](data:image/png;base64,...)
#
# * 𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗚𝗮𝘁𝗲𝘀: Similar to classical logic gates (AND, OR, NOT), quantum gates manipulate qubit states. However, unlike classical gates, quantum gates can handle superposition and entanglement, allowing for a broader range of operations. Common gates include:
#
# Pauli-X gate : (quantum equivalent of NOT, flips qubit)
# Hadamard gate : (puts qubit into superposition)
# CNOT gate : (entangles two qubits)
# Ry and Rz gates:These are quantum gates that rotate the state of a qubit around different axes (Y and Z) of the Bloch sphere (a visual representation of a qubit's state). They're used to manipulate the qubit's state.
#
# These gates are the building blocks of quantum algorithms used to process information at a quantum level.
#
# * 𝗦𝘂𝗽𝗲𝗿𝗽𝗼𝘀𝗶𝘁𝗶𝗼𝗻: A qubit can be in a state of 0, 1, or both simultaneously, unlike classical bits that are either 0 or 1. This ability allows quantum computers to perform multiple calculations at the same time.
#
# ![image.png](data:image/png;base64,...)
# * 𝗘𝗻𝘁𝗮𝗻𝗴𝗹𝗲𝗺𝗲𝗻𝘁: Qubits can become entangled, meaning the state of one qubit is dependent on another, no matter the physical distance between them. This correlation provides powerful ways to transmit and process information.
#
# ![image.png](data:image/png;base64,...)
#
# * 𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗖𝗶𝗿𝗰𝘂𝗶𝘁𝘀: Just like classical circuits that perform logical operations, quantum circuits are made of quantum gates and are used to manipulate qubits. These circuits are sequences of gates that carry out quantum computations. The complexity of these circuits is key to solving quantum problems.
#
# ![image.png](data:image/png;base64,...)
#
# * 𝗤𝘂𝗮𝗻𝘁𝘂𝗺 𝗜𝗻𝘁𝗲𝗿𝗳𝗲𝗿𝗲𝗻𝗰𝗲: Quantum states can interfere with each other, where the probability of obtaining certain results is enhanced, while others are suppressed, allowing quantum computers to focus on correct solutions.
#
# * 𝗠𝗲𝗮𝘀𝘂𝗿𝗲:This operation observes the state of a qubit, collapsing its quantum state into a classical bit (0 or 1). It's how we extract information from a quantum system.
#
# * 𝗔𝗲𝗿𝗦𝗶𝗺𝘂𝗹𝗮𝘁𝗼𝗿:This is a simulator that mimics the behavior of a quantum computer on a classical computer. It's useful for testing and developing quantum algorithms without access to actual quantum hardware.
#
# * 𝗧𝗿𝗮𝗻𝘀𝗽𝗶𝗹𝗲:This process converts a high-level quantum circuit into a format that can be run on a specific quantum device or simulator, optimizing it for the target system.
#
# * 𝗦𝗵𝗼𝘁𝘀:In quantum computing, a "shot" is a single execution of a quantum circuit. Because quantum measurements are probabilistic, we typically run a circuit many times (shots) to get a distribution of results.

# %% [markdown]
# ## 5.Quick Jupyter Notebook Guide Creating A Bell State.

# %% [markdown]
# ### 1. Setting up Qiskit

# %%
 # Install Qiskit by running:
# !pip install qiskit --upgrade
# !pip install qiskit-aer --upgrade

# %% [markdown]
# ### Installation Inspection

# %%
pip show qiskit
# Out:
# Name: qiskit
# Version: 1.2.4
# Summary: An open-source SDK for working with quantum computers at the level of extended quantum circuits, operators, and primitives.
# Home-page: https://www.ibm.com/quantum/qiskit
# Author:
# Author-email: Qiskit Development Team <qiskit@us.ibm.com>
# License: Apache 2.0
# Location: C:\Users\danny.valerio\anaconda3\envs\Quantum\Lib\site-packages
# Requires: dill, numpy, python-dateutil, rustworkx, scipy, stevedore, symengine, sympy, typing-extensions
# Required-by: qiskit-aer, qiskit-ibm-runtime
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show qiskit-aer
# Out:
# Name: qiskit-aer
# Version: 0.15.1
# Summary: Aer - High performance simulators for Qiskit
# Home-page: https://github.com/Qiskit/qiskit-aer
# Author: AER Development Team
# Author-email: qiskit@us.ibm.com
# License: Apache 2.0
# Location: C:\Users\danny.valerio\anaconda3\envs\Quantum\Lib\site-packages
# Requires: numpy, psutil, qiskit, scipy
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2. Importing Qiskit and Required Modules
# * Here, we import QuantumCircuit for creating our quantum circuit, Aer for using simulators, and the transpile function to run our circuit.

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3. Creating a Quantum Circuit
#
# * We will start by creating a quantum circuit with two qubits.

# %%
# Step 1: Create a quantum circuit with 2 qubits and 2 classical bits
qc = QuantumCircuit(2, 2)

# %% [markdown]
# ### 4. Applying Quantum Gates to Create a Bell State
# #### To create a Bell state, we need to apply two operations:
#
# ##### * Hadamard Gate (H-gate): 𝗥𝗲𝗮𝗹 𝗟𝗶𝗳𝗲 𝗔𝗻𝗮𝗹𝗼𝗴𝘆 - This puts the first qubit in a superposition.This gate puts the first qubit (Alice) into a superposition of states |0⟩ and |1⟩, like giving her a pill that makes her both awake and asleep at the same time.
#
# ##### * qc.h(0) applies a Hadamard gate on qubit 0, creating a superposition state:
#
# ##### * CNOT Gate: 𝗥𝗲𝗮𝗹 𝗟𝗶𝗳𝗲 𝗔𝗻𝗮𝗹𝗼𝗴𝘆 - This entangles the second qubit with the first.The second qubit (Bob) is now entangled with Alice’s state. The pill now affects both Alice and Bob, connecting their states. If Alice is awake (|1⟩), Bob will be awake (|1⟩) too. If Alice is asleep (|0⟩), Bob will be asleep (|0⟩) as well.
#
# ##### * qc.cx(0, 1) applies a CNOT gate. The first qubit (qubit 0) is the control qubit, and the second qubit (qubit 1) is the target qubit. This gate entangles the two qubits.

# %%
# Apply Hadamard gate on the first qubit
qc.h(0)

# Apply CNOT gate with the first qubit as control and second qubit as target
qc.cx(0, 1)

# %% [markdown]
# ### 5. Measuring the Qubits
# * To observe the quantum state, we need to measure the qubits.
#
# * This measures qubit 0 and stores the result in classical bit 0, and measures qubit 1 into classical bit 1*

# %%
# Measure the qubits
qc.measure([0, 1], [0, 1])

# %% [markdown]
# ### 6.Circuit Simulation
#
# * Simulates the quantum circuit and the measurement results (counts) to ensure that the circuit is correct and returning values.

# %%
 # Create a simulator
simulator = AerSimulator()

# Transpile the circuit for the simulator
compiled_circuit = transpile(qc, simulator)

# Run the simulation and get the result
result = simulator.run(compiled_circuit).result()

# %% [markdown]
#  ### 7. Visualize the Circuit

# %%
# Print the circuit
print("Quantum Circuit:\n")
print(qc.draw())
# Out:
# Quantum Circuit:
#
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %% [markdown]
# ### 8. Print the Result

# %%
# Print the result
counts = result.get_counts()
print("\nMeasurement Results (Counts):\n", counts)
# Out:
# Measurement Results (Counts):
#  {'00': 512, '11': 512}

# %% [markdown]
# ## 6.Interpretation
#
# This result is typical of a Bell state measurement in quantum computing.
#
# Bell states: These are maximally entangled quantum states of two qubits. There are four Bell states, but this result looks like it's from one of two specific Bell states:
# |Φ+⟩ = (|00⟩ + |11⟩) / √2
# or
# |Φ-⟩ = (|00⟩ - |11⟩) / √2
# Measurement results:
#
# '00': 539 counts
# '11': 485 counts
#
#
# #### 𝗘𝘅𝗽𝗹𝗮𝗻𝗮𝘁𝗶𝗼𝗻:
#
# The measurement shows only two outcomes: '00' and '11'. This is consistent with the Bell states |Φ+⟩ or |Φ-⟩.
# In an ideal Bell state, you'd expect exactly 50% '00' and 50% '11' measurements.
# The actual results (539 vs 485) are close to a 50-50 split, with some statistical variation.
#
#
# #### 𝗦𝗶𝗴𝗻𝗶𝗳𝗶𝗰𝗮𝗻𝗰𝗲:
#
# This result strongly suggests that the qubits were indeed in a Bell state.
# The slight imbalance between '00' and '11' could be due to:
# a) Normal statistical fluctuations
# b) Small imperfections in the quantum circuit or measurement process
# c) Decoherence or noise in the quantum system
#
#
# 𝗧𝗼𝘁𝗮𝗹 𝗺𝗲𝗮𝘀𝘂𝗿𝗲𝗺𝗲𝗻𝘁𝘀: 539 + 485 = 1024, which is a common number in quantum computing.

# %% [markdown]
# ## 7.Conclusion
#
# * Bell states are a cornerstone of quantum mechanics, showcasing the mind-bending concept of entanglement. These special quantum states, where two particles are so deeply linked they act as one regardless of distance, may seem strange at first. But don't be discouraged! As you explore further, you'll find that understanding Bell states opens doors to fascinating quantum technologies. Keep your curiosity alive – you're at the beginning of an exciting journey into the quantum world!

# %% [markdown]
# ## 8. References
#
# * Regarding the multi-qubit teleportation protocol and the possibility of recovering only the projection on the z-axis of the outcomes, this does not represent any problem, since the same thing happens in all physical computer platforms such as those of IBM Q Experience (Quantum 2023), and also on an optical table, that is, we only measure in one axis, the z (Sisodia et al. 2017a(Sisodia et al. , 2017b(Sisodia et al. , 2021Sisodia 2020)

# %% [markdown]
# ### YOU DID IT!

# %%
print("Congratulations! You've taken your first steps into quantum ML for drug discovery!")
# Out:
# Congratulations! You've taken your first steps into quantum ML for drug discovery!
